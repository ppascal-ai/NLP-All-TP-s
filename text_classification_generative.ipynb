# %%
# !pip install transformers>=4.41.2 accelerate>=0.31.0
# !pip install transformers sentence-transformers openai
# !pip install -U datasets
# Out:
# zsh:1: 4.41.2 not found
# Requirement already satisfied: transformers in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (4.57.3)
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.1.2-py3-none-any.whl.metadata (16 kB)
# Collecting openai
#   Downloading openai-2.9.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from sentence-transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: Pillow in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from sentence-transformers) (12.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from openai) (4.12.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.12.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.6)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Downloading sentence_transformers-5.1.2-py3-none-any.whl (488 kB)
# Downloading openai-2.9.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.9 MB/s  0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.12.0-cp312-cp312-macosx_11_0_arm64.whl (319 kB)
# Installing collected packages: jiter, distro, openai, sentence-transformers
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [sentence-transformers]/4 [sentence-transformers]
# Successfully installed distro-1.9.0 jiter-0.12.0 openai-2.9.0 sentence-transformers-5.1.2
# Requirement already satisfied: datasets in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (4.4.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from datasets) (2.2.6)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (4.12.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/Labs/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %% [markdown]
# # Using a task-specific model

# %%
from datasets import load_dataset

# Load our data
data = load_dataset("rotten_tomatoes")
data
# Out:
# README.md: 0.00B [00:00, ?B/s]
# train.parquet:   0%|          | 0.00/699k [00:00<?, ?B/s]
# validation.parquet:   0%|          | 0.00/90.0k [00:00<?, ?B/s]
# test.parquet:   0%|          | 0.00/92.2k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/8530 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1066 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1066 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 8530
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 1066
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 1066
#     })
# })

# %% [markdown]
# don't know why but i couldn't use gpu on colab so device='cuda' wasn't working :/

# %%
from transformers import pipeline
import torch

model_path = "cardiffnlp/twitter-roberta-base-sentiment-latest"

# Dynamically set the device to 'cuda' if available, otherwise 'cpu'
device = 0 if torch.cuda.is_available() else -1

# load model into pipeline
pipe = pipeline(
    model=model_path,
    tokenizer=model_path,
    return_all_scores=True,
    device=device
)
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu

# %%
import numpy as np
from tqdm import tqdm
from transformers.pipelines.pt_utils import KeyDataset

# Run inference
y_pred = []
for output in tqdm(pipe(KeyDataset(data["test"], "text")), total=len(data["test"])):
    negative_score = output[0]["score"]
    positive_score = output[2]["score"]
    assignment = np.argmax([negative_score, positive_score])
    y_pred.append(assignment)
# Out:
# 100%|██████████| 1066/1066 [03:05<00:00,  5.76it/s]

# %%
from sklearn.metrics import classification_report

def evaluate_performance(y_true, y_pred):
    """Create and print the classification report"""
    performance = classification_report(
        y_true, y_pred,
        target_names=["Negative Review", "Positive Review"]
    )
    print(performance)

# %%
evaluate_performance(data["test"]["label"], y_pred)
# Out:
#                  precision    recall  f1-score   support
#
# Negative Review       0.76      0.88      0.81       533
# Positive Review       0.86      0.72      0.78       533
#
#        accuracy                           0.80      1066
#       macro avg       0.81      0.80      0.80      1066
#    weighted avg       0.81      0.80      0.80      1066

# %% [markdown]
# # Classification tasks with embeddings

# %% [markdown]
# ## Supervised classification with embeddings

# %%
from sentence_transformers import SentenceTransformer

# Load model
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')

# Convert text to embeddings
train_embeddings = model.encode(data["train"]["text"], show_progress_bar=True)
test_embeddings = model.encode(data["test"]["text"], show_progress_bar=True)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/267 [00:00<?, ?it/s]
# Batches:   0%|          | 0/34 [00:00<?, ?it/s]

# %%
from sentence_transformers import SentenceTransformer
sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
embeddings = model.encode(sentences)
print(embeddings)
# Out:
# [[ 0.02250261 -0.0782918  -0.02303076 ... -0.00827925  0.02652694
#   -0.00201898]
#  [ 0.04170239  0.00109739 -0.01553419 ... -0.02181625 -0.06359357
#   -0.00875283]]

# %%
train_embeddings.shape
# Out:
# (8530, 768)

# %%
from sklearn.linear_model import LogisticRegression

# Train a Logistic Regression on our train embeddings
clf = LogisticRegression(random_state=42)
clf.fit(train_embeddings, data["train"]["label"])
# Out:
# LogisticRegression(random_state=42)

# %%
# Predict previously unseen instances
y_pred = clf.predict(test_embeddings)
evaluate_performance(data["test"]["label"], y_pred)
# Out:
#                  precision    recall  f1-score   support
#
# Negative Review       0.85      0.86      0.85       533
# Positive Review       0.86      0.85      0.85       533
#
#        accuracy                           0.85      1066
#       macro avg       0.85      0.85      0.85      1066
#    weighted avg       0.85      0.85      0.85      1066

# %% [markdown]
# ## What if we do not have labeled data : unsupervised use case

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

# Average the embeddings of all documents in each target label
df = pd.DataFrame(np.hstack([train_embeddings, np.array(data["train"]["label"]).reshape(-1, 1)]))
averaged_target_embeddings = df.groupby(768).mean().values

# Find the best matching embeddings between evaluation documents and target embeddings
sim_matrix = cosine_similarity(test_embeddings, averaged_target_embeddings)
y_pred = np.argmax(sim_matrix, axis=1)

# Evaluate the model
evaluate_performance(data["test"]["label"], y_pred)
# Out:
#                  precision    recall  f1-score   support
#
# Negative Review       0.85      0.84      0.84       533
# Positive Review       0.84      0.85      0.84       533
#
#        accuracy                           0.84      1066
#       macro avg       0.84      0.84      0.84      1066
#    weighted avg       0.84      0.84      0.84      1066

# %%
# Create embeddings for our labels
label_embeddings = model.encode(["A negative review",  "A positive review"])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Find the best matching label for each document
sim_matrix = cosine_similarity(test_embeddings, label_embeddings)
y_pred = np.argmax(sim_matrix, axis=1)

# %%
evaluate_performance(data["test"]["label"], y_pred)
# Out:
#                  precision    recall  f1-score   support
#
# Negative Review       0.78      0.77      0.78       533
# Positive Review       0.77      0.79      0.78       533
#
#        accuracy                           0.78      1066
#       macro avg       0.78      0.78      0.78      1066
#    weighted avg       0.78      0.78      0.78      1066

# %% [markdown]
# # Text classification with generative models

# %%
! pip install groq
# Out:
# Collecting groq
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.37.1

# %%
! export GROQ_API_KEY="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"

# %%
sample_text = data["test"]["text"][0]
print(f"Review: {sample_text}\n")
# Out:
# Review: lovingly photographed in the manner of a golden book sprung to life , stuart little 2 manages sweetness largely without stickiness .

# %%
import os
from groq import Groq
from dotenv import load_dotenv

load_dotenv()

# Set the GROQ_API_KEY directly in the Python environment
os.environ["GROQ_API_KEY"] = "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"

client = Groq(
    api_key=os.getenv("GROQ_API_KEY"),
)

chat_completion = client.chat.completions.create(
    model="meta-llama/llama-4-scout-17b-16e-instruct",
    messages=[
        {
            "role": "system",
            "content": "You are a sentiment classifier. Respond with only 'positive' or 'negative'."
        },
        {
            "role": "user",
            "content": f"Classify the sentiment of this movie review: {sample_text}"
        }
    ],
    temperature=0,
    max_tokens=10

)
print(chat_completion.choices[0].message.content)
# Out:
# positive

# %%
chat_completion = client.chat.completions.create(
    model="meta-llama/llama-4-scout-17b-16e-instruct",
    messages=[
        {
            "role": "system",
            "content": "You are a sentiment classifier. Rate the sentiment as a number between 0 (negative) and 1 (positive). Respond with only the number."
        },
        {
            "role": "user",
            "content": f"Rate the sentiment of this movie review: {sample_text}"
        }
    ],
    temperature=0,
    max_tokens=10

)
print(chat_completion.choices[0].message.content)
# Out:
# 0.8

# %%
def groq_generation(prompt, model="meta-llama/llama-4-scout-17b-16e-instruct"):
  message = [
        {
            "role": "system",
            "content": "You are a sentiment classifier. Rate the sentiment as a number between 0 (negative) and 1 (positive). Respond with only the number."
        },
        {
            "role": "user",
            "content": f"Rate the sentiment of this movie review: {prompt}"
        }
  ]
  chat_completion = client.chat.completions.create(
      model=model,
      messages=message,
      temperature=0,
      max_tokens=10
    )
  return chat_completion.choices[0].message.content

# %%
groq_generation(sample_text)
# Out:
# '0.87'

# %%
#predictions = [groq_generation(prompt) for doc in tqdm(data["test"]["text"])]

# %%
#y_pred = [int(pred) for pred in predictions]
#evaluate_performance(data["test"]["label"], y_pred)

# %% [markdown]
# # Text2Text transfert transformers

# %% [markdown]
# same don't have access to gpu so device='cuda' doesn't work

# %%
# Load our model
pipe = pipeline(
    "text2text-generation",
    model="google/flan-t5-small",
    device=device
)
# Out:
# Device set to use cpu

# %%
# Prepare our data
prompt = "Is the following sentence positive or negative? "
data = data.map(lambda example: {"t5": prompt + example['text']})
data
# Out:
# Map:   0%|          | 0/8530 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1066 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1066 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 't5'],
#         num_rows: 8530
#     })
#     validation: Dataset({
#         features: ['text', 'label', 't5'],
#         num_rows: 1066
#     })
#     test: Dataset({
#         features: ['text', 'label', 't5'],
#         num_rows: 1066
#     })
# })

# %%
# Run inference
y_pred = []
for output in tqdm(pipe(KeyDataset(data["test"], "t5")), total=len(data["test"])):
    text = output[0]["generated_text"]
    y_pred.append(0 if text == "negative" else 1)
# Out:
# 100%|██████████| 1066/1066 [05:27<00:00,  3.26it/s]

# %%
evaluate_performance(data["test"]["label"], y_pred)
# Out:
#                  precision    recall  f1-score   support
#
# Negative Review       0.83      0.85      0.84       533
# Positive Review       0.85      0.83      0.84       533
#
#        accuracy                           0.84      1066
#       macro avg       0.84      0.84      0.84      1066
#    weighted avg       0.84      0.84      0.84      1066
